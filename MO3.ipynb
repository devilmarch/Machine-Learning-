# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("/content/wine.data")
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %% [markdown]
#  Извлеките из данных признаки и классы. Класс записан в первом
#  столбце (три варианта), признаки в столбцах со второго по по
# следний.

# %%
df.columns = ['Class','Alcohol','MalicAcid','Ash','AlcalinityOfAsh','Magnesium','TotalPhenols','Flavanoids','NonflavanoidPhenols','Proanthocyanins','ColorIntensity','Hue','OD280_OD315OfDilutedWines','Proline']
target = df.Class#вычленяем массив
model = df.drop(['Class'], axis=1)#Вычленяем модель из датасет
df
# Out:
#      Class  Alcohol  MalicAcid   Ash  AlcalinityOfAsh  Magnesium  \
# 0        1    13.20       1.78  2.14             11.2        100
# 1        1    13.16       2.36  2.67             18.6        101
# 2        1    14.37       1.95  2.50             16.8        113
# 3        1    13.24       2.59  2.87             21.0        118
# 4        1    14.20       1.76  2.45             15.2        112
# ..     ...      ...        ...   ...              ...        ...
# 172      3    13.71       5.65  2.45             20.5         95
# 173      3    13.40       3.91  2.48             23.0        102
# 174      3    13.27       4.28  2.26             20.0        120
# 175      3    13.17       2.59  2.37             20.0        120
# 176      3    14.13       4.10  2.74             24.5         96
#
#      TotalPhenols  Flavanoids  NonflavanoidPhenols  Proanthocyanins  \
# 0            2.65        2.76                 0.26             1.28
# ...

# %% [markdown]
# Оценку качества необходимо провести методом кросс-валидации по
#  5 блокам (5-fold). Создайте генератор разбиений, который переме
# шивает выборку перед формированием блоков (shuffle=True). Для
# воспроизводимости результата, создавайте генератор KFold с фик
# сированным параметром random_state=42. В качестве меры каче
# ства используйте долю верных ответов (accuracy).

# %%
X = df[['Alcohol','MalicAcid','Ash','AlcalinityOfAsh','Magnesium','TotalPhenols','Flavanoids','NonflavanoidPhenols','Proanthocyanins','ColorIntensity','Hue','OD280_OD315OfDilutedWines','Proline']]
y = df['Class']
kf = KFold(n_splits=5, shuffle=True, random_state=42)
k_values = range(1, 51)
accuracy_scores = []

# %% [markdown]
#  Найдите точность классификации на кросс-валидации для метода
#  k ближайших соседей (sklearn.neighbors.KNeighborsClassifier), при
#  k от 1 до 50. При каком k получилось оптимальное качество? Чему
#  оно равно (число в интервале от 0 до 1)? Данные результаты и
#  будут ответами на вопросы 1 и 2.

# %%
neigh = KNeighborsClassifier (n_neighbors= 1)
scores = cross_val_score(neigh, X, y, cv = 5)
print("Значения правильности перекрестной проверки: {}".format(scores))
# Out:
# Значения правильности перекрестной проверки: [0.80555556 0.63888889 0.68571429 0.74285714 0.77142857]

# %%
print("Средняя правильность перекрестной проверки: {:.2f}".format(scores.mean()))
# Out:
# Средняя правильность перекрестной проверки: 0.73

# %%
for k in k_values:
    model = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(model, X, y, cv=kf, scoring='accuracy')
    accuracy_scores.append(scores.mean())

best_k = np.argmax(accuracy_scores) + 1  # +1 т.к. индексы с 0
best_accuracy = accuracy_scores[best_k - 1]

print("Без масштабирования:")
print(f"Оптимальное k: {best_k}")
print(f"Лучшая точность: {best_accuracy:.4f}")
# Out:
# Без масштабирования:
# Оптимальное k: 1
# Лучшая точность: 0.7352

# %% [markdown]
#  Произведите масштабирование признаков с помощью функции
#  sklearn.preprocessing.scale. Снова найдите оптимальное k на кросс
# валидации. Какое значение k получилось оптимальным после приведения при
# знаков к одному масштабу? Как изменилось значение качества?
#  Приведите ответы на вопросы 3 и 4.

# %%
# 5. Масштабирование признаков
X_scaled = scale(X)

# 6. Кросс-валидация с масштабированием
scaled_accuracy_scores = []

for k in k_values:
    model = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(model, X_scaled, y, cv=kf, scoring='accuracy')
    scaled_accuracy_scores.append(scores.mean())

best_k_scaled = np.argmax(scaled_accuracy_scores) + 1
best_accuracy_scaled = scaled_accuracy_scores[best_k_scaled - 1]

print("\nС масштабированием:")
print(f"Оптимальное k: {best_k_scaled}")
print(f"Лучшая точность: {best_accuracy_scaled:.4f}")
print(f"Улучшение точности: {best_accuracy_scaled - best_accuracy:.4f}")
# Out:
# С масштабированием:
# Оптимальное k: 28
# Лучшая точность: 0.9773
# Улучшение точности: 0.2421
